# %% [markdown]
# <a href="https://colab.research.google.com/github/aburijal26/Social-Media-Analytics/blob/main/Social%20Media%20Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
xls = pd.ExcelFile('/content/drive/MyDrive/Hakuhodo Digital Indonesia/Dummy DataSet Hakuhodo Digital Indonesia.xlsx')

# %%
instagram_feed = pd.read_excel(xls, 'Instagram Feed')
facebook = pd.read_excel(xls, 'Facebook')
instagram_story = pd.read_excel(xls, 'Instagram Story')
twitter = pd.read_excel(xls, 'Twitter')
linkedin = pd.read_excel(xls, 'LinkedIn')
# Out:
# /usr/local/lib/python3.8/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# # Instagram Feed

# %%
instagram_feed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 284 non-null    datetime64[ns]
#  1   Week                 284 non-null    int64
#  2   day                  284 non-null    object
#  3   Content              284 non-null    object
#  4   Type                 284 non-null    object
#  5   Time                 60 non-null     object
#  6   Like                 284 non-null    float64
#  7   Comment              268 non-null    float64
#  8   Share                280 non-null    float64
#  9   Save                 270 non-null    float64
#  10  Total Interaction    284 non-null    int64
#  11  Reach                284 non-null    float64
#  12  Impressions          284 non-null    float64
#  13  ER                   284 non-null    float64
#  14  Month                284 non-null    object
# ...

# %%
instagram_feed.describe()
# Out:
#              Week          Like      Comment       Share        Save  \
# count  284.000000    284.000000   268.000000  280.000000  270.000000
# mean    23.302817    220.126761    19.455224    8.407143    2.281481
# std     12.585532   2818.489600   153.472862   30.260019   12.627139
# min      1.000000     10.000000     0.000000    0.000000    0.000000
# 25%     12.750000     20.000000     0.000000    2.000000    0.000000
# 50%     23.000000     34.000000     0.000000    4.000000    1.000000
# 75%     35.000000     65.500000     2.000000    6.000000    2.000000
# max     44.000000  47543.000000  1968.000000  386.000000  196.000000
#
#        Total Interaction         Reach   Impressions          ER    Year  \
# count         284.000000  2.840000e+02  2.840000e+02  284.000000   284.0
# mean          248.943662  1.274730e+04  1.401067e+04    0.113484  2022.0
# std          2972.074918  1.652947e+05  1.678981e+05    0.076344     0.0
# ...

# %%
instagram_feed.isna().sum()
# Out:
# Date                     0
# Week                     0
# day                      0
# Content                  0
# Type                     0
# Time                   224
# Like                     0
# Comment                 16
# Share                    4
# Save                    14
# Total Interaction        0
# Reach                    0
# Impressions              0
# ER                       0
# Month                    0
# Year                     0
# Product/Non Product      0
# Detail Name              0
# Explore                257
# Home                   253
# Profile                253
# Other                  254
# Hashtag                269
# Unnamed: 23            284
# Unnamed: 24            281
# Unnamed: 25            282
# Unnamed: 26            283
# Unnamed: 27            283
# dtype: int64

# %%
instagram_feed
# Out:
#                    Date  Week        day        Content      Type Time   Like  \
# 0   2022-01-01 00:00:00     1   Saturday    Instagram 1     IMAGE  NaN   26.0
# 1   2022-01-02 00:00:00     1     Sunday    Instagram 2  CAROUSEL  NaN   62.0
# 2   2022-01-04 00:00:00     1    Tuesday    Instagram 3  CAROUSEL  NaN   21.0
# 3   2022-01-05 00:00:00     2  Wednesday    Instagram 4  CAROUSEL  NaN   30.0
# 4   2022-01-06 00:00:00     2   Thursday    Instagram 5  CAROUSEL  NaN   21.0
# ..                  ...   ...        ...            ...       ...  ...    ...
# 279 2022-10-25 12:10:00    43    Tuesday  Instagram 280  CAROUSEL  NaN   45.0
# 280 2022-10-02 08:10:00    40     Sunday  Instagram 281     IMAGE  NaN  108.0
# 281 2022-10-25 16:10:00    43    Tuesday  Instagram 282  CAROUSEL  NaN   52.0
# 282 2022-10-24 19:10:00    43     Monday  Instagram 283  CAROUSEL  NaN   38.0
# 283 2022-10-28 10:10:00    44     Friday  Instagram 284     IMAGE  NaN   43.0
#
# ...

# %%
instagram_feed.drop(['Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27','Explore','Home','Profile','Other','Hashtag'], inplace = True, axis= 1)

# %%
instagram_feed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 284 non-null    datetime64[ns]
#  1   Week                 284 non-null    int64
#  2   day                  284 non-null    object
#  3   Content              284 non-null    object
#  4   Type                 284 non-null    object
#  5   Time                 60 non-null     object
#  6   Like                 284 non-null    float64
#  7   Comment              268 non-null    float64
#  8   Share                280 non-null    float64
#  9   Save                 270 non-null    float64
#  10  Total Interaction    284 non-null    int64
#  11  Reach                284 non-null    float64
#  12  Impressions          284 non-null    float64
#  13  ER                   284 non-null    float64
#  14  Month                284 non-null    object
# ...

# %%
instagram_feed.isna().sum()
# Out:
# Date                     0
# Week                     0
# day                      0
# Content                  0
# Type                     0
# Time                   224
# Like                     0
# Comment                 16
# Share                    4
# Save                    14
# Total Interaction        0
# Reach                    0
# Impressions              0
# ER                       0
# Month                    0
# Year                     0
# Product/Non Product      0
# Detail Name              0
# dtype: int64

# %%
instagram_feed['Time'] = instagram_feed['Date'].dt.time

# %%
instagram_feed['Comment'] = instagram_feed['Comment'].fillna(instagram_feed['Comment'].median())

# %%
instagram_feed['Share'] = instagram_feed['Share'].fillna(instagram_feed['Share'].median())

# %%
instagram_feed['Save'] = instagram_feed['Save'].fillna(instagram_feed['Save'].median())

# %%
instagram_feed = instagram_feed.astype({"Like":'int', "Comment":'int', "Share":'int', "Save":'int', "Reach":'int', "Impressions":'int'})

# %%
instagram_feed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 284 non-null    datetime64[ns]
#  1   Week                 284 non-null    int64
#  2   day                  284 non-null    object
#  3   Content              284 non-null    object
#  4   Type                 284 non-null    object
#  5   Time                 284 non-null    object
#  6   Like                 284 non-null    int64
#  7   Comment              284 non-null    int64
#  8   Share                284 non-null    int64
#  9   Save                 284 non-null    int64
#  10  Total Interaction    284 non-null    int64
#  11  Reach                284 non-null    int64
#  12  Impressions          284 non-null    int64
#  13  ER                   284 non-null    float64
#  14  Month                284 non-null    object
# ...

# %%
instagram_feed.isna().sum()
# Out:
# Date                   0
# Week                   0
# day                    0
# Content                0
# Type                   0
# Time                   0
# Like                   0
# Comment                0
# Share                  0
# Save                   0
# Total Interaction      0
# Reach                  0
# Impressions            0
# ER                     0
# Month                  0
# Year                   0
# Product/Non Product    0
# Detail Name            0
# dtype: int64

# %%
instagram_feed
# Out:
#                    Date  Week        day        Content      Type      Time  \
# 0   2022-01-01 00:00:00     1   Saturday    Instagram 1     IMAGE  00:00:00
# 1   2022-01-02 00:00:00     1     Sunday    Instagram 2  CAROUSEL  00:00:00
# 2   2022-01-04 00:00:00     1    Tuesday    Instagram 3  CAROUSEL  00:00:00
# 3   2022-01-05 00:00:00     2  Wednesday    Instagram 4  CAROUSEL  00:00:00
# 4   2022-01-06 00:00:00     2   Thursday    Instagram 5  CAROUSEL  00:00:00
# ..                  ...   ...        ...            ...       ...       ...
# 279 2022-10-25 12:10:00    43    Tuesday  Instagram 280  CAROUSEL  12:10:00
# 280 2022-10-02 08:10:00    40     Sunday  Instagram 281     IMAGE  08:10:00
# 281 2022-10-25 16:10:00    43    Tuesday  Instagram 282  CAROUSEL  16:10:00
# 282 2022-10-24 19:10:00    43     Monday  Instagram 283  CAROUSEL  19:10:00
# 283 2022-10-28 10:10:00    44     Friday  Instagram 284     IMAGE  10:10:00
#
# ...

# %% [markdown]
# # Facebook

# %%
facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Post Message         246 non-null    object
#  1   Type                 246 non-null    object
#  2   Posted               246 non-null    datetime64[ns]
#  3   Time                 28 non-null     object
#  4   Total Reach          246 non-null    float64
#  5   Total Impressions    246 non-null    float64
#  6   Engagement           246 non-null    float64
#  7   like                 246 non-null    float64
#  8   comment              102 non-null    float64
#  9   share                105 non-null    float64
#  10  Engagement Rate (%)  246 non-null    float64
#  11  Month                246 non-null    object
#  12  Year                 246 non-null    int64
#  13  Product/Non Product  246 non-null    object
#  14  Detail Name          246 non-null    object
# ...

# %%
facebook.describe()
# Out:
#          Total Reach  Total Impressions    Engagement          like  \
# count     246.000000         246.000000    246.000000    246.000000
# mean     1094.605691        2110.869919    207.617886    205.353659
# std     15037.456688       30789.496821   3171.216903   3148.123055
# min        43.000000          45.000000      1.000000      1.000000
# 25%        91.000000         100.250000      3.000000      3.000000
# 50%       124.000000         132.000000      5.000000      4.000000
# 75%       162.750000         176.500000      7.000000      6.000000
# max    235987.000000      483061.000000  49744.000000  49381.000000
#
#           comment       share  Engagement Rate (%)    Year  Post Type  \
# count  102.000000  105.000000           246.000000   246.0        0.0
# mean     3.558824    0.514286             0.045147  2022.0        NaN
# std     33.148801    2.753020             0.029648     0.0        NaN
# min      0.000000    0.000000             0.010309  2022.0        NaN
# ...

# %%
facebook.isna().sum()
# Out:
# Post Message             0
# Type                     0
# Posted                   0
# Time                   218
# Total Reach              0
# Total Impressions        0
# Engagement               0
# like                     0
# comment                144
# share                  141
# Engagement Rate (%)      0
# Month                    0
# Year                     0
# Product/Non Product      0
# Detail Name              0
# Unnamed: 15            239
# Post Type              246
# Detail Post            246
# dtype: int64

# %%
facebook
# Out:
#      Post Message   Type              Posted Time  Total Reach  \
# 0      Facebook 1  Photo 2022-01-01 00:00:00  NaN        141.0
# 1      Facebook 2  Photo 2022-01-04 02:22:00  NaN        152.0
# 2      Facebook 3  Photo 2022-01-05 05:46:00  NaN        126.0
# 3      Facebook 4  Photo 2022-01-06 01:19:00  NaN        147.0
# 4      Facebook 5  Photo 2022-01-12 03:45:00  NaN        135.0
# ..            ...    ...                 ...  ...          ...
# 241  Facebook 242  Video 2022-10-02 00:00:00  NaN         84.0
# 242  Facebook 243  Photo 2022-10-05 00:00:00  NaN        140.0
# 243  Facebook 244  Photo 2022-10-06 00:00:00  NaN        124.0
# 244  Facebook 245  Photo 2022-10-20 00:00:00  NaN        148.0
# 245  Facebook 246  Photo 2022-10-05 00:00:00  NaN        187.0
#
#      Total Impressions  Engagement  like  comment  share  Engagement Rate (%)  \
# 0                152.0         5.0   4.0      NaN    NaN             0.035461
# ...

# %%
facebook.drop(['Unnamed: 15', 'Post Type', 'Detail Post'], inplace = True, axis= 1)

# %%
facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Post Message         246 non-null    object
#  1   Type                 246 non-null    object
#  2   Posted               246 non-null    datetime64[ns]
#  3   Time                 28 non-null     object
#  4   Total Reach          246 non-null    float64
#  5   Total Impressions    246 non-null    float64
#  6   Engagement           246 non-null    float64
#  7   like                 246 non-null    float64
#  8   comment              102 non-null    float64
#  9   share                105 non-null    float64
#  10  Engagement Rate (%)  246 non-null    float64
#  11  Month                246 non-null    object
#  12  Year                 246 non-null    int64
#  13  Product/Non Product  246 non-null    object
#  14  Detail Name          246 non-null    object
# ...

# %%
facebook.isna().sum()
# Out:
# Post Message             0
# Type                     0
# Posted                   0
# Time                   218
# Total Reach              0
# Total Impressions        0
# Engagement               0
# like                     0
# comment                144
# share                  141
# Engagement Rate (%)      0
# Month                    0
# Year                     0
# Product/Non Product      0
# Detail Name              0
# dtype: int64

# %%
facebook['Time'] = facebook['Posted'].dt.time

# %%
facebook['comment'] = facebook['comment'].fillna(facebook['comment'].median())

# %%
facebook['share'] = facebook['share'].fillna(facebook['share'].median())

# %%
facebook = facebook.astype({"Total Reach":'int', "Total Impressions":'int', "Engagement":'int', "like":'int', "comment":'int', "share":'int'})

# %%
facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Post Message         246 non-null    object
#  1   Type                 246 non-null    object
#  2   Posted               246 non-null    datetime64[ns]
#  3   Time                 246 non-null    object
#  4   Total Reach          246 non-null    int64
#  5   Total Impressions    246 non-null    int64
#  6   Engagement           246 non-null    int64
#  7   like                 246 non-null    int64
#  8   comment              246 non-null    int64
#  9   share                246 non-null    int64
#  10  Engagement Rate (%)  246 non-null    float64
#  11  Month                246 non-null    object
#  12  Year                 246 non-null    int64
#  13  Product/Non Product  246 non-null    object
#  14  Detail Name          246 non-null    object
# ...

# %%
facebook.isna().sum()
# Out:
# Post Message           0
# Type                   0
# Posted                 0
# Time                   0
# Total Reach            0
# Total Impressions      0
# Engagement             0
# like                   0
# comment                0
# share                  0
# Engagement Rate (%)    0
# Month                  0
# Year                   0
# Product/Non Product    0
# Detail Name            0
# dtype: int64

# %%
facebook
# Out:
#      Post Message   Type              Posted      Time  Total Reach  \
# 0      Facebook 1  Photo 2022-01-01 00:00:00  00:00:00          141
# 1      Facebook 2  Photo 2022-01-04 02:22:00  02:22:00          152
# 2      Facebook 3  Photo 2022-01-05 05:46:00  05:46:00          126
# 3      Facebook 4  Photo 2022-01-06 01:19:00  01:19:00          147
# 4      Facebook 5  Photo 2022-01-12 03:45:00  03:45:00          135
# ..            ...    ...                 ...       ...          ...
# 241  Facebook 242  Video 2022-10-02 00:00:00  00:00:00           84
# 242  Facebook 243  Photo 2022-10-05 00:00:00  00:00:00          140
# 243  Facebook 244  Photo 2022-10-06 00:00:00  00:00:00          124
# 244  Facebook 245  Photo 2022-10-20 00:00:00  00:00:00          148
# 245  Facebook 246  Photo 2022-10-05 00:00:00  00:00:00          187
#
#      Total Impressions  Engagement  like  comment  share  Engagement Rate (%)  \
# ...

# %% [markdown]
# # Instagram Story

# %%
instagram_story.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                377 non-null    datetime64[ns]
#  1   Week                377 non-null    int64
#  2   Share               98 non-null     float64
#  3   Replies             133 non-null    float64
#  4   Link Clicks         160 non-null    float64
#  5   Profile Visits      268 non-null    float64
#  6   Website Click       33 non-null     float64
#  7   Sticker Special 3s  109 non-null    float64
#  8   Email               3 non-null      float64
#  9   Follow              94 non-null     float64
#  10  Total Responses     75 non-null     float64
#  11  Reach               377 non-null    float64
#  12  Impressions         377 non-null    float64
#  13  Total Interaction   377 non-null    int64
#  14  ER                  377 non-null    float64
# ...

# %%
instagram_story.describe()
# Out:
#              Week      Share     Replies  Link Clicks  Profile Visits  \
# count  377.000000  98.000000  133.000000   160.000000      268.000000
# mean    25.140584   0.357143    0.864662     2.818750        2.880597
# std     11.889736   1.150974    1.560798     4.588572        2.994489
# min      1.000000   0.000000    0.000000     0.000000        0.000000
# 25%     15.000000   0.000000    0.000000     0.000000        1.000000
# 50%     26.000000   0.000000    0.000000     1.000000        2.000000
# 75%     35.000000   0.000000    1.000000     3.000000        3.000000
# max     44.000000   7.000000   10.000000    29.000000       26.000000
#
#        Website Click  Sticker Special 3s  Email     Follow  Total Responses  \
# count      33.000000          109.000000    3.0  94.000000        75.000000
# mean        2.000000            2.385321    3.0   0.138298        18.026667
# std         1.030776            8.294251    1.0   0.579229        12.348513
# ...

# %%
instagram_story.isna().sum()
# Out:
# Date                    0
# Week                    0
# Share                 279
# Replies               244
# Link Clicks           217
# Profile Visits        109
# Website Click         344
# Sticker Special 3s    268
# Email                 374
# Follow                283
# Total Responses       302
# Reach                   0
# Impressions             0
# Total Interaction       0
# ER                      0
# Month                   0
# Year                    0
# Post Type             155
# Unnamed: 18           339
# Unnamed: 19           377
# Unnamed: 20           377
# Unnamed: 21           367
# Unnamed: 22           367
# Unnamed: 23           375
# Unnamed: 24           377
# Unnamed: 25           377
# Unnamed: 26           377
# Unnamed: 27           377
# Unnamed: 28           377
# Unnamed: 29           377
# Unnamed: 30           374
# Unnamed: 31           374
# dtype: int64

# %%
instagram_story
# Out:
#                    Date  Week  Share  Replies  Link Clicks  Profile Visits  \
# 0   2022-01-01 00:00:00     1    NaN      NaN          NaN             NaN
# 1   2022-01-04 00:00:00     2    NaN      NaN          NaN             4.0
# 2   2022-01-05 00:00:00     2    NaN      NaN          NaN             1.0
# 3   2022-01-06 00:00:00     2    NaN      NaN          NaN             1.0
# 4   2022-01-08 00:00:00     2    NaN      NaN          NaN             2.0
# ..                  ...   ...    ...      ...          ...             ...
# 372 2022-10-08 14:10:00    41    0.0      0.0          0.0             2.0
# 373 2022-10-27 16:10:00    44    0.0      0.0          1.0             1.0
# 374 2022-10-28 10:10:00    44    0.0      0.0          0.0             1.0
# 375 2022-10-09 17:10:00    42    0.0      0.0          0.0             1.0
# 376 2022-10-06 16:10:00    41    0.0      0.0          0.0             0.0
#
# ...

# %%
instagram_story.drop(['Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31'], inplace = True, axis= 1)

# %%
instagram_story.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                377 non-null    datetime64[ns]
#  1   Week                377 non-null    int64
#  2   Share               98 non-null     float64
#  3   Replies             133 non-null    float64
#  4   Link Clicks         160 non-null    float64
#  5   Profile Visits      268 non-null    float64
#  6   Website Click       33 non-null     float64
#  7   Sticker Special 3s  109 non-null    float64
#  8   Email               3 non-null      float64
#  9   Follow              94 non-null     float64
#  10  Total Responses     75 non-null     float64
#  11  Reach               377 non-null    float64
#  12  Impressions         377 non-null    float64
#  13  Total Interaction   377 non-null    int64
#  14  ER                  377 non-null    float64
# ...

# %%
instagram_story.isna().sum()
# Out:
# Date                    0
# Week                    0
# Share                 279
# Replies               244
# Link Clicks           217
# Profile Visits        109
# Website Click         344
# Sticker Special 3s    268
# Email                 374
# Follow                283
# Total Responses       302
# Reach                   0
# Impressions             0
# Total Interaction       0
# ER                      0
# Month                   0
# Year                    0
# Post Type             155
# dtype: int64

# %%
instagram_story['Share'] = instagram_story['Share'].fillna(instagram_story['Share'].median())

# %%
instagram_story['Replies'] = instagram_story['Replies'].fillna(instagram_story['Replies'].median())

# %%
instagram_story['Link Clicks'] = instagram_story['Link Clicks'].fillna(instagram_story['Link Clicks'].median())

# %%
instagram_story['Profile Visits'] = instagram_story['Profile Visits'].fillna(instagram_story['Profile Visits'].median())

# %%
instagram_story['Website Click'] = instagram_story['Website Click'].fillna(instagram_story['Website Click'].median())

# %%
instagram_story['Sticker Special 3s'] = instagram_story['Sticker Special 3s'].fillna(instagram_story['Sticker Special 3s'].median())

# %%
instagram_story['Email'] = instagram_story['Email'].fillna(instagram_story['Email'].median())

# %%
instagram_story['Follow'] = instagram_story['Follow'].fillna(instagram_story['Follow'].median())

# %%
instagram_story['Total Responses'] = instagram_story['Total Responses'].fillna(instagram_story['Total Responses'].median())

# %%
instagram_story['Post Type'] = instagram_story['Post Type'].fillna(instagram_story['Post Type'].mode()[0])

# %%
instagram_story = instagram_story.astype({"Share":'int', "Replies":'int', "Link Clicks":'int', "Profile Visits":'int', "Website Click":'int', "Sticker Special 3s":'int', "Email":'int', "Follow":'int', "Total Responses":'int', "Reach":'int', "Impressions":'int', "Total Interaction":'int'})

# %%
instagram_story.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                377 non-null    datetime64[ns]
#  1   Week                377 non-null    int64
#  2   Share               377 non-null    int64
#  3   Replies             377 non-null    int64
#  4   Link Clicks         377 non-null    int64
#  5   Profile Visits      377 non-null    int64
#  6   Website Click       377 non-null    int64
#  7   Sticker Special 3s  377 non-null    int64
#  8   Email               377 non-null    int64
#  9   Follow              377 non-null    int64
#  10  Total Responses     377 non-null    int64
#  11  Reach               377 non-null    int64
#  12  Impressions         377 non-null    int64
#  13  Total Interaction   377 non-null    int64
#  14  ER                  377 non-null    float64
# ...

# %%
instagram_story.isna().sum()
# Out:
# Date                  0
# Week                  0
# Share                 0
# Replies               0
# Link Clicks           0
# Profile Visits        0
# Website Click         0
# Sticker Special 3s    0
# Email                 0
# Follow                0
# Total Responses       0
# Reach                 0
# Impressions           0
# Total Interaction     0
# ER                    0
# Month                 0
# Year                  0
# Post Type             0
# dtype: int64

# %%
instagram_story
# Out:
#                    Date  Week  Share  Replies  Link Clicks  Profile Visits  \
# 0   2022-01-01 00:00:00     1      0        0            1               2
# 1   2022-01-04 00:00:00     2      0        0            1               4
# 2   2022-01-05 00:00:00     2      0        0            1               1
# 3   2022-01-06 00:00:00     2      0        0            1               1
# 4   2022-01-08 00:00:00     2      0        0            1               2
# ..                  ...   ...    ...      ...          ...             ...
# 372 2022-10-08 14:10:00    41      0        0            0               2
# 373 2022-10-27 16:10:00    44      0        0            1               1
# 374 2022-10-28 10:10:00    44      0        0            0               1
# 375 2022-10-09 17:10:00    42      0        0            0               1
# 376 2022-10-06 16:10:00    41      0        0            0               0
#
# ...

# %% [markdown]
# # Twitter

# %%
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   time                 337 non-null    datetime64[ns]
#  1   hour                 316 non-null    object
#  2   impressions          337 non-null    float64
#  3   Engagement           337 non-null    float64
#  4   Engagement rate      337 non-null    float64
#  5   Month                337 non-null    object
#  6   Week                 337 non-null    int64
#  7   Post Type            26 non-null     object
#  8   Product/Non Product  337 non-null    object
#  9   Detail Name          337 non-null    object
#  10  Year                 337 non-null    int64
#  11  test er              337 non-null    float64
#  12  selisih              337 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 34.4+ KB

# %%
twitter.describe()
# Out:
#        impressions  Engagement  Engagement rate        Week    Year  \
# count   337.000000  337.000000       337.000000  337.000000   337.0
# mean    170.011869   10.581602         0.081194   24.836795  2022.0
# std     552.714066   10.764249         0.046222   12.767614     0.0
# min       8.000000    0.000000         0.000000    1.000000  2022.0
# 25%      67.000000    4.000000         0.048780   13.000000  2022.0
# 50%      99.000000    8.000000         0.075758   26.000000  2022.0
# 75%     139.000000   13.000000         0.107143   37.000000  2022.0
# max    9518.000000  101.000000         0.300000   44.000000  2022.0
#
#           test er       selisih
# count  337.000000  3.370000e+02
# mean     0.081194 -1.811270e-08
# std      0.046222  1.696694e-07
# min      0.000000 -5.000000e-07
# 25%      0.048780  0.000000e+00
# 50%      0.075758  0.000000e+00
# 75%      0.107143  0.000000e+00
# max      0.300000  4.915254e-07

# %%
twitter.isna().sum()
# Out:
# time                     0
# hour                    21
# impressions              0
# Engagement               0
# Engagement rate          0
# Month                    0
# Week                     0
# Post Type              311
# Product/Non Product      0
# Detail Name              0
# Year                     0
# test er                  0
# selisih                  0
# dtype: int64

# %%
twitter
# Out:
#           time      hour  impressions  Engagement  Engagement rate     Month  \
# 0   2022-01-01       NaN        167.0        11.0         0.065868  Jan-2022
# 1   2022-01-02       NaN        308.0        28.0         0.090909  Jan-2022
# 2   2022-01-04       NaN        194.0        13.0         0.067010  Jan-2022
# 3   2022-01-05       NaN        195.0        19.0         0.097436  Jan-2022
# 4   2022-01-06       NaN        127.0        11.0         0.086614  Jan-2022
# ..         ...       ...          ...         ...              ...       ...
# 332 2022-10-26  10:09:00         24.0         1.0         0.041667  Oct-2022
# 333 2022-10-27  03:10:00         63.0         2.0         0.031746  Oct-2022
# 334 2022-10-27  09:52:00         62.0         6.0         0.096774  Oct-2022
# 335 2022-10-27  06:40:00         55.0         4.0         0.072727  Oct-2022
# 336 2022-10-28  03:18:00        153.0        19.0         0.124183  Oct-2022
#
# ...

# %%
twitter['hour'] = twitter['hour'].fillna(twitter['hour'].mode()[0])

# %%
twitter['Post Type'] = twitter['Post Type'].fillna(twitter['Post Type'].mode()[0])

# %%
twitter = twitter.astype({"impressions":'int', "Engagement":'int'})

# %%
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   time                 337 non-null    datetime64[ns]
#  1   hour                 337 non-null    object
#  2   impressions          337 non-null    int64
#  3   Engagement           337 non-null    int64
#  4   Engagement rate      337 non-null    float64
#  5   Month                337 non-null    object
#  6   Week                 337 non-null    int64
#  7   Post Type            337 non-null    object
#  8   Product/Non Product  337 non-null    object
#  9   Detail Name          337 non-null    object
#  10  Year                 337 non-null    int64
#  11  test er              337 non-null    float64
#  12  selisih              337 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(5)
# memory usage: 34.4+ KB

# %%
twitter.isna().sum()
# Out:
# time                   0
# hour                   0
# impressions            0
# Engagement             0
# Engagement rate        0
# Month                  0
# Week                   0
# Post Type              0
# Product/Non Product    0
# Detail Name            0
# Year                   0
# test er                0
# selisih                0
# dtype: int64

# %%
twitter
# Out:
#           time      hour  impressions  Engagement  Engagement rate     Month  \
# 0   2022-01-01  06:13:00          167          11         0.065868  Jan-2022
# 1   2022-01-02  06:13:00          308          28         0.090909  Jan-2022
# 2   2022-01-04  06:13:00          194          13         0.067010  Jan-2022
# 3   2022-01-05  06:13:00          195          19         0.097436  Jan-2022
# 4   2022-01-06  06:13:00          127          11         0.086614  Jan-2022
# ..         ...       ...          ...         ...              ...       ...
# 332 2022-10-26  10:09:00           24           1         0.041667  Oct-2022
# 333 2022-10-27  03:10:00           63           2         0.031746  Oct-2022
# 334 2022-10-27  09:52:00           62           6         0.096774  Oct-2022
# 335 2022-10-27  06:40:00           55           4         0.072727  Oct-2022
# 336 2022-10-28  03:18:00          153          19         0.124183  Oct-2022
#
# ...

# %% [markdown]
# #LinkedIn

# %%
linkedin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Update title              327 non-null    object
#  1   Update title name         327 non-null    object
#  2   Campaign name             1 non-null      object
#  3   Created date              327 non-null    datetime64[ns]
#  4   Audience                  181 non-null    object
#  5   Impressions               327 non-null    float64
#  6   Video views               68 non-null     float64
#  7   Clicks                    327 non-null    float64
#  8   Click through rate (CTR)  327 non-null    float64
#  9   Likes                     327 non-null    float64
#  10  Comments                  327 non-null    float64
#  11  Shares                    327 non-null    float64
#  12  Follows                   2 non-null      float64
# ...

# %%
linkedin.describe()
# Out:
#         Impressions  Video views       Clicks  Click through rate (CTR)  \
# count    327.000000    68.000000   327.000000                327.000000
# mean     838.727829   121.426471   112.743119                  0.125474
# std     1957.817140   374.004083   337.939382                  0.136909
# min      140.000000     2.000000     0.000000                  0.000000
# 25%      343.000000     9.000000     8.000000                  0.019672
# 50%      509.000000    24.000000    32.000000                  0.039548
# 75%      744.000000    72.750000   120.000000                  0.221139
# max    28448.000000  2912.000000  5355.000000                  0.778621
#
#             Likes    Comments      Shares  Follows  Engagement rate  \
# count  327.000000  327.000000  327.000000      2.0       327.000000
# mean    16.296636    0.348624    0.458716      0.0         0.149338
# std     24.028117    3.157549    0.827430      0.0         0.135453
# ...

# %%
linkedin.isna().sum()
# Out:
# Update title                  0
# Update title name             0
# Campaign name               326
# Created date                  0
# Audience                    146
# Impressions                   0
# Video views                 259
# Clicks                        0
# Click through rate (CTR)      0
# Likes                         0
# Comments                      0
# Shares                        0
# Follows                     325
# Engagement rate               0
# Month                         0
# Engagement                    0
# Week                          0
# Year                          0
# Post Type                   259
# Product/Non Product           0
# Detail Name                   0
# Manual tag                  262
# Average Engagement rate       1
# dtype: int64

# %%
linkedin
# Out:
#      Update title Update title name Campaign name Created date       Audience  \
# 0      LinkedIn 1           Organic           NaN   2022-01-01  All followers
# 1      LinkedIn 2           Organic           NaN   2022-01-02  All followers
# 2      LinkedIn 3           Organic           NaN   2022-01-05  All followers
# 3      LinkedIn 4           Organic           NaN   2022-01-07  All followers
# 4      LinkedIn 5           Organic           NaN   2022-01-08  All followers
# ..            ...               ...           ...          ...            ...
# 322  LinkedIn 323           Organic           NaN   2022-09-08            NaN
# 323  LinkedIn 324           Organic           NaN   2022-09-07            NaN
# 324  LinkedIn 325           Organic           NaN   2022-10-06            NaN
# 325  LinkedIn 326           Organic           NaN   2022-09-09            NaN
# 326  LinkedIn 327           Organic           NaN   2022-10-01            NaN
#
# ...

# %%
linkedin.drop(['Campaign name', 'Follows', 'Manual tag'], inplace = True, axis= 1)

# %%
linkedin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Update title              327 non-null    object
#  1   Update title name         327 non-null    object
#  2   Created date              327 non-null    datetime64[ns]
#  3   Audience                  181 non-null    object
#  4   Impressions               327 non-null    float64
#  5   Video views               68 non-null     float64
#  6   Clicks                    327 non-null    float64
#  7   Click through rate (CTR)  327 non-null    float64
#  8   Likes                     327 non-null    float64
#  9   Comments                  327 non-null    float64
#  10  Shares                    327 non-null    float64
#  11  Engagement rate           327 non-null    float64
#  12  Month                     327 non-null    object
# ...

# %%
linkedin.isna().sum()
# Out:
# Update title                  0
# Update title name             0
# Created date                  0
# Audience                    146
# Impressions                   0
# Video views                 259
# Clicks                        0
# Click through rate (CTR)      0
# Likes                         0
# Comments                      0
# Shares                        0
# Engagement rate               0
# Month                         0
# Engagement                    0
# Week                          0
# Year                          0
# Post Type                   259
# Product/Non Product           0
# Detail Name                   0
# Average Engagement rate       1
# dtype: int64

# %%
linkedin['Audience'] = linkedin['Audience'].fillna(linkedin['Audience'].mode()[0])

# %%
linkedin['Video views'] = linkedin['Video views'].fillna(linkedin['Video views'].mode()[0])

# %%
linkedin['Post Type'] = linkedin['Post Type'].fillna(linkedin['Post Type'].mode()[0])

# %%
linkedin['Average Engagement rate'] = linkedin['Average Engagement rate'].fillna(linkedin['Average Engagement rate'].mean())

# %%
linkedin = linkedin.astype({"Impressions":'int', "Video views":'int', "Clicks":'int', "Likes":'int', "Comments":'int', "Shares":'int', "Engagement":'int'})

# %%
linkedin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Update title              327 non-null    object
#  1   Update title name         327 non-null    object
#  2   Created date              327 non-null    datetime64[ns]
#  3   Audience                  327 non-null    object
#  4   Impressions               327 non-null    int64
#  5   Video views               327 non-null    int64
#  6   Clicks                    327 non-null    int64
#  7   Click through rate (CTR)  327 non-null    float64
#  8   Likes                     327 non-null    int64
#  9   Comments                  327 non-null    int64
#  10  Shares                    327 non-null    int64
#  11  Engagement rate           327 non-null    float64
#  12  Month                     327 non-null    object
# ...

# %%
linkedin.isna().sum()
# Out:
# Update title                0
# Update title name           0
# Created date                0
# Audience                    0
# Impressions                 0
# Video views                 0
# Clicks                      0
# Click through rate (CTR)    0
# Likes                       0
# Comments                    0
# Shares                      0
# Engagement rate             0
# Month                       0
# Engagement                  0
# Week                        0
# Year                        0
# Post Type                   0
# Product/Non Product         0
# Detail Name                 0
# Average Engagement rate     0
# dtype: int64

# %%
linkedin
# Out:
#      Update title Update title name Created date       Audience  Impressions  \
# 0      LinkedIn 1           Organic   2022-01-01  All followers          589
# 1      LinkedIn 2           Organic   2022-01-02  All followers         3396
# 2      LinkedIn 3           Organic   2022-01-05  All followers          988
# 3      LinkedIn 4           Organic   2022-01-07  All followers          500
# 4      LinkedIn 5           Organic   2022-01-08  All followers         1106
# ..            ...               ...          ...            ...          ...
# 322  LinkedIn 323           Organic   2022-09-08  All followers          206
# 323  LinkedIn 324           Organic   2022-09-07  All followers          228
# 324  LinkedIn 325           Organic   2022-10-06  All followers          213
# 325  LinkedIn 326           Organic   2022-09-09  All followers          192
# 326  LinkedIn 327           Organic   2022-10-01  All followers          231
#
# ...

# %% [markdown]
# # Export Dataset

# %%
with pd.ExcelWriter('Dummy DataSet Hakuhodo Digital Indonesia Clean.xlsx') as writer:
  instagram_feed.to_excel(writer, 'Instagram Feed')
  facebook.to_excel(writer, 'Facebook')
  instagram_story.to_excel(writer, 'Instagram Story')
  twitter.to_excel(writer, 'Twitter')
  linkedin.to_excel(writer, 'LinkedIn')

# %% [markdown]
# # Visualization
#
#
# *   [Social Media Dashboard](https://datastudio.google.com/reporting/cbc0b331-db5d-462a-96f9-77c4c169a91b)
